# %% [markdown]
# ### MLE for a single PHU with multiplicative noise - Public Health Data Case

# %%
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys

from scipy.optimize import minimize

##### CHANGE HERE #############
### Use the time up to which you need to estimate the parameters of sigmoid
dt = 0.1
tstart = 0
tlim = 200
t = np.arange(tstart, tlim, 1)


### keep it always starting at 0
tmoh = np.arange(0, tlim, dt)

ndiv = 1/dt

##### CHANGE HERE #############

###### If you have your own data, load it here #######
### Currently loaded infection data from MOH, for April 2020 to March 2021

PHU_path = '/Users/sudhipv/documents/sum_of_sigmoid/PHU_Data/'
datapath = '/Users/sudhipv/documents/sum_of_sigmoid/data/'
figpath = '/Users/sudhipv/documents/sum_of_sigmoid/figs/'
Data = np.zeros([365,4])

files = os.listdir(PHU_path)

target_file1 = f'{PHU_path}/30-Toronto.csv'
target_file2 = f'{PHU_path}/34-York.csv'
target_file3 = f'{PHU_path}/04-Durham.csv'
target_file4 = f'{PHU_path}/22-PeelRegion.csv'

Data[:,0] = np.genfromtxt(target_file1, delimiter=',')
Data[:,1] = np.genfromtxt(target_file2, delimiter=',')
Data[:,2] = np.genfromtxt(target_file3, delimiter=',')
Data[:,3] = np.genfromtxt(target_file4, delimiter=',')


population_by_phu = np.genfromtxt(f'{PHU_path}/population_by_phu.csv', delimiter=',')


N_city = 1
# Preallocate compartments
S = np.zeros((len(tmoh),N_city))
E = np.zeros((len(tmoh),N_city))
I = np.zeros((len(tmoh),N_city))
R = np.zeros((len(tmoh),N_city))
D = np.zeros((len(tmoh),N_city))
N = np.zeros((len(tmoh),N_city))


I_model = np.zeros((len(t),N_city))
I_synthetic = np.zeros((len(t),N_city))

##### CHANGE HERE #############
## Observed data
I_synthetic[:,0] =  Data[tstart:tlim,0]

# file = np.genfromtxt(f'{datapath}/brandon_synthetic_data_case2.dat', delimiter=',')
# I_synthetic[tstart:tlim,0] = file[tstart:tlim]
##############################

L_Force = np.zeros((len(tmoh),N_city))

##### CHANGE HERE #############
total = population_by_phu[29,1]
##### CHANGE HERE #############
 
##### CHANGE HERE #############
E[0,0] = Data[0,0]
I[0,0] = Data[0,0]
##############################
R[0,0] = 0
D[0,0] = 0
N[0,0] = total
S[0,0] = N[0,0] - E[0,0] - I[0,0] - R[0,0] - D[0,0]



# Model parameters - Taken from Southern Ontario - COVID MBE paper
gamma_e = 1/15
gamma_i = 1/5
gamma_r = 1/11
gamma_d = 1/750

beta_e = np.zeros((len(tmoh),N_city)) 
beta_i = np.zeros((len(tmoh),N_city))

beta_calibrated = np.zeros((len(tmoh),N_city))


print("initial infected",I[0,0])

print("total population",total)


#### PEEL - 234 , 1451022

#### Toronto - 430 , 2794356

### York - 212, 1173334

### Durham - 94   - 696992


mpl.rcParams.update({'font.size':14})
# Out:
# initial infected 430.0
# total population 2794356.0

# %%
nparam = 8
param = np.ones(nparam)
##### CHANGE HERE ############
### Use the parameters which needs to be included in the sum of sigmoids model for MLE estimation
### When doing sequntial calibration, include all the parameters until that time.

################### Toronto ##########################################################

# original    Synthetic Data values
a0 =   0.14
a1 =  -0.08
t1 =  20
a2 =   0.04
t2 =  35
a3 =   -0.06
t3 = 60
a4 =  0.02
t4 = 80
a5 =  0.07
t5 = 140
a6 =  -0.02
t6 = 180
a7 =  0.04
t7 = 190
# a8 =  -0.015
# t8 = 230  


################### Durham ##########################################################

# True parameter values with which synthetic data is generated
# a0 =   0.14
# a1 =  -0.115
# t1 =  20
# a2 =   0.06
# t2 =  35
# a3 =   -0.05
# t3 = 65
# a4 =  0.035
# t4 = 90
# a5 =  0.06
# t5 = 140
# a6 =  -0.075
# t6 = 180
# a7 =  0.06
# t7 = 190
# a8 =  -0.025
# t8 = 250


# true_param = np.array([a0,a1,a2,a3])

### Initial guesses of your parameters
# a0 =  0.1
# a1 = -0.08
# t1 =  20
# a2 =  0.05
# t2 =  40
# a3 =  -0.04
# t3 = 60
# a4 =  0.06
# t4 = 90
# a5 =  0.05
# t5 = 120
# a6 =  0.01
# t6 = 140
# a7 =  0.05
# t7 = 180
# a8 =  -0.03
# t8 = 200


#### MLE computed sequentially with 2 parameters each

# a0 = 0.14034937 
# a1 = -0.13
# a2 = 0.08849439 
# a3 = -0.11343904
# a4 = 0.06655221 
# a5 = 0.05820387


beta_i[:,0] = a0  + a1/(1 + np.exp((t1-tmoh)))  \
+ a2/(1 + np.exp((t2-tmoh))) + a3/(1 + np.exp((t3-tmoh))) \
+ a4/(1 + np.exp((t4-tmoh))) + a5/(1 + np.exp((t5-tmoh)))  \
+ a6/(1 + np.exp((t6-tmoh))) + a7/(1 + np.exp((t7-tmoh))) \
# + a8/(1 + np.exp((t8-tmoh)))

beta_e[:,0] = beta_i[:,0]


#### DEFINE THE PARAMETERS TO BE ESTIMATED 

param = np.array([a0,a1,a2,a3,a4,a5,a6,a7])

# %%
### Fixed values of noise strength
##### CHANGE HERE ##########

### Select a suitable  noise strength for multiplicative noise
mu = 0 # mean 
sigma = 0.1 # standard deviation 


FoI = np.zeros((len(tmoh),1))
    
for kk in range(1,len(tmoh)):

  FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

  S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
  E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
  
  I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
  R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
  D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
  N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]

  if( kk%ndiv == 0):
      idxmoh = int(kk/ndiv)



fig1, ax1 = plt.subplots(figsize=(6, 4))
ax1.set_xlim([0,tlim])
ax1.set_xlabel('Time (days)')
ax1.set_ylabel('Infected cases') 
ax1.grid()
plt.plot(t, I_synthetic[:,0], '*', markersize=6, label='Observed data')
plt.plot(tmoh, I[:,0], '-',linewidth=2, label='Initial model output')
ax1.legend(loc='best')
# plt.savefig('./figs/noisy_data.pdf',  bbox_inches='tight')
plt.show()



fig2, ax2 = plt.subplots(figsize=(6, 4))
ax2.set_xlim([0,tlim])
ax2.set_xlabel('Time (days)')
ax2.set_ylabel('Infection rate') 
ax2.grid()
plt.plot(tmoh, beta_i[:,0], label='Sum of sigmoid model')
ax1.legend(loc='best')
# plt.savefig('./figs/beta.pdf',  bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Applying scipy optimization library

# %%
def loglikelihood(param):
      
    idxmoh = 1
    idxdata = 0

    loglik = 0

    FoI = np.zeros((len(tmoh),1))

    # print("parameter is",param)

############### CHANGE HERE #################
###### Update the model of beta to include the parameter which needs to be estimated along with the known paramters until that time
    beta_i[:,0] = param[0] + param[1]/(1 + np.exp((t1-tmoh))) \
    + param[2]/(1 + np.exp((t2-tmoh))) + param[3]/(1 + np.exp((t3-tmoh))) \
    + param[4]/(1 + np.exp((t4-tmoh))) + param[5]/(1 + np.exp((t5-tmoh))) 
    + param[6]/(1 + np.exp((t6-tmoh)))  + param[7]/(1 + np.exp((t7-tmoh))) 
    # + param[0]/(1 + np.exp((t8-tmoh)))
    

    beta_e[:,0] = beta_i[:,0]   



    for kk in range(1,len(tmoh)):

            FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

            S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
            E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
            I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
            R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
            D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
            N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]


            ## For collecting the model output only at data points
            if( kk%ndiv == 0 ):
                idxmoh = int(kk/ndiv)


                if(tstart !=0):

                    if(idxmoh >=tstart and idxmoh<tlim):
                        

                        multiplier = (1/(np.sqrt(2*np.pi)*sigma * I[kk,0]))


                        err = (I_synthetic[idxdata,0] - I[kk,0])**2

                        # log likelihood
                        loglik = loglik  + np.log(multiplier) - (err/(2*(sigma * I[kk,0])**2)) 

                        idxdata+=1
                
                else:

                    multiplier = (1/(np.sqrt(2*np.pi)*sigma * I[kk,0]))


                    err = (I_synthetic[idxmoh,0] -  I[kk,0])**2

                    # log likelihood
                    loglik = loglik  + np.log(multiplier) - (err/(2*(sigma * I[kk,0])**2)) 

                    if(np.isnan(loglik)):
                         print("I is", I[kk,0])
                         print("kk is", kk, idxmoh)
                         print("param,", param )
                         print("beta,", beta_i[:,0] )
                         break

    
    return -loglik



options_bfgs = {
    'gtol': 1e-12,  # Gradient norm tolerance for convergence
    # 'ftol': 1e-16,
    'disp': True,  # Display convergence messages
    'eps': 1e-8
}

options_nm = {
    'disp': True,  # Display convergence messages
}


val = 0.05
bounds = [(a0-val, a0+val), (a1-val, a1+val), (a2-val, a2+val), (a3-val, a3+val), (a4-val, a4+val), (a5-val, a5+val), (a6-val, a6+val), (a7-val, a7+val)]
          #   (a2-val, a2+val),(a3-val, a3+val),(a4-val, a4+val),(a5-val, a5+val)]

### To be used for Synthetic data when you know true parameter values
# errors = []
# iterations = []

# def callback(xk):
#     print(f"Current parameter values: {xk}")
#     # err = np.linalg.norm(xk - trueparam)/np.linalg.norm(trueparam)
#     # print("relative error is", err)
#     errors.append(err)
#     iterations.append(len(errors))
 


res = minimize(loglikelihood, param,method='L-BFGS-B', options = options_bfgs, bounds=bounds)

# res = minimize(loglikelihood, param,method='Nelder-Mead',bounds=bounds, options=options_nm)


print(res)
param_mle = res.x

print("initial guesses" ,param)
print("MLE value", res.x)
# print("True parameter values", true_param)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.90454D+03    |proj g|=  5.00000D-02
#
# At iterate    1    f=  1.40239D+03    |proj g|=  5.04490D-02
#
# At iterate    2    f=  1.39794D+03    |proj g|=  5.04317D-02
#
# At iterate    3    f=  1.38750D+03    |proj g|=  5.02523D-02
#
# At iterate    4    f=  1.37406D+03    |proj g|=  4.99572D-02
#
# At iterate    5    f=  1.33326D+03    |proj g|=  5.06559D-02
#
# At iterate    6    f=  1.28783D+03    |proj g|=  5.14963D-02
#
# At iterate    7    f=  1.24819D+03    |proj g|=  5.18698D-02
#
# At iterate    8    f=  1.24458D+03    |proj g|=  5.24374D-02
#
# At iterate    9    f=  1.24438D+03    |proj g|=  5.35155D-02
#
# At iterate   10    f=  1.24421D+03    |proj g|=  5.35364D-02
#
# At iterate   11    f=  1.24354D+03    |proj g|=  5.35987D-02
#
# At iterate   12    f=  1.24213D+03    |proj g|=  5.40189D-02
#
# At iterate   13    f=  1.23894D+03    |proj g|=  5.48287D-02
#
# At iterate   14    f=  1.23396D+03    |proj g|=  5.61508D-02
#
# At iterate   15    f=  1.22896D+03    |proj g|=  5.74442D-02
#
# At iterate   16    f=  1.22744D+03    |proj g|=  5.76922D-02
#
# At iterate   17    f=  1.22730D+03    |proj g|=  5.27432D-02
#
# At iterate   18    f=  1.22710D+03    |proj g|=  5.74475D-02
#
# At iterate   19    f=  1.22710D+03    |proj g|=  5.74076D-02
#
# At iterate   20    f=  1.22636D+03    |proj g|=  5.38825D-02
#
# At iterate   21    f=  1.22393D+03    |proj g|=  5.35487D-02
#
# At iterate   22    f=  1.22152D+03    |proj g|=  5.42667D-02
#
# At iterate   23    f=  1.22029D+03    |proj g|=  6.10150D-02
#
# At iterate   24    f=  1.21990D+03    |proj g|=  5.52936D-02
#
# At iterate   25    f=  1.21971D+03    |proj g|=  6.22640D-02
#
# At iterate   26    f=  1.21920D+03    |proj g|=  6.26598D-02
#
# At iterate   27    f=  1.21839D+03    |proj g|=  6.33765D-02
#
# At iterate   28    f=  1.21696D+03    |proj g|=  6.49978D-02
#
# At iterate   29    f=  1.21690D+03    |proj g|=  6.50892D-02
#
# At iterate   30    f=  1.21577D+03    |proj g|=  6.67055D-02
#
# At iterate   31    f=  1.21543D+03    |proj g|=  6.74201D-02
#
# At iterate   32    f=  1.21540D+03    |proj g|=  5.83379D-02
#
# At iterate   33    f=  1.21540D+03    |proj g|=  5.82914D-02
#
# At iterate   34    f=  1.21539D+03    |proj g|=  5.82355D-02
#
# At iterate   35    f=  1.21534D+03    |proj g|=  5.81004D-02
#
# At iterate   36    f=  1.21525D+03    |proj g|=  5.80641D-02
#
# At iterate   37    f=  1.21502D+03    |proj g|=  5.83444D-02
#
# At iterate   38    f=  1.21502D+03    |proj g|=  5.83465D-02
#
# At iterate   39    f=  1.21454D+03    |proj g|=  5.95436D-02
#
# At iterate   40    f=  1.21415D+03    |proj g|=  7.26651D-02
#
# At iterate   41    f=  1.21387D+03    |proj g|=  7.23292D-02
#
# At iterate   42    f=  1.21309D+03    |proj g|=  7.35271D-02
#
# At iterate   43    f=  1.21174D+03    |proj g|=  7.78245D-02
#
# At iterate   44    f=  1.21116D+03    |proj g|=  7.75466D-02
#
# At iterate   45    f=  1.21101D+03    |proj g|=  6.99930D-02
#
# At iterate   46    f=  1.21099D+03    |proj g|=  7.00745D-02
#
# At iterate   47    f=  1.21099D+03    |proj g|=  7.59861D-02
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1210.9855025149266
#         x: [ 1.478e-01 -1.060e-01  6.008e-02 -6.319e-02  2.398e-02
#              7.732e-02 -2.000e-02  4.000e-02]
#       nit: 48
#       jac: [ 8.972e-02  8.131e-02  6.769e-02  3.811e-02  2.151e-02
#              4.115e-03  0.000e+00  0.000e+00]
#      nfev: 513
#      njev: 57
#  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
# initial guesses [ 0.14 -0.08  0.04 -0.06  0.02  0.07 -0.02  0.04]
# MLE value [ 0.14778039 -0.10598664  0.060082   -0.0631869   0.02397656  0.07732259
#  -0.02        0.04      ]
#
# At iterate   48    f=  1.21099D+03    |proj g|=  6.76891D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     48     57     54     0     0   6.769D-02   1.211D+03
#   F =   1210.9855025149266
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %% [markdown]
# ### MLE Fit

# %%
########### CHANGE HERE #############
### Add the necessary parameter values which are already calibrated along with the current parameters ##############

beta_i[:,0] = param_mle[0] + param_mle[1]/(1 + np.exp((t1-tmoh))) \
+ param_mle[2]/(1 + np.exp((t2-tmoh))) + param_mle[3]/(1 + np.exp((t3-tmoh))) \
+ param_mle[4]/(1 + np.exp((t4-tmoh)))  + param_mle[5]/(1 + np.exp((t5-tmoh))) \
+ param_mle[6]/(1 + np.exp((t6-tmoh))) + param_mle[7]/(1 + np.exp((t7-tmoh))) 
# + param_mle[0]/(1 + np.exp((t8-tmoh)))



###########################################

beta_e[:,0] = beta_i[:,0]
 

FoI = np.zeros((len(tmoh),1))
    
for kk in range(1,len(tmoh)):

  FoI[kk,0] = beta_e[kk-1,0] * (E[kk-1,0] + I[kk-1,0]) / N[kk-1,0]

  S[kk,0] = S[kk-1,0] + dt*(- FoI[kk,0] * S[kk-1,0])
  E[kk,0] = E[kk-1,0] + dt*(FoI[kk,0]*S[kk-1,0] - (gamma_i + gamma_e)*E[kk-1,0])
  
  I[kk,0] = I[kk-1,0] + dt*(gamma_i*E[kk-1,0] - (gamma_r + gamma_d)*I[kk-1,0])
  R[kk,0] = R[kk-1,0] + dt*(gamma_e*E[kk-1,0] + gamma_r*I[kk-1,0])
  D[kk,0] = D[kk-1,0] + dt*(gamma_d*I[kk-1,0])
  N[kk,0] = S[kk,0] +  E[kk,0] + I[kk,0] + R[kk,0]



## True model output for synthetic data
# [t_brandon,S_true,E_true,I_true,R_true,D_true,b_true] = np.loadtxt(f'{datapath}/brandon_synthetic_truth_case2.dat')

# file2 = np.loadtxt(f'{datapath}/brandon_synthetic_truth_case2.csv')
# I_true_model = file2[0:len(tmoh)]


fig1, ax1 = plt.subplots(figsize=(6, 4))
plt.plot(t[:tlim], I_synthetic[:tlim,0], '*', markersize=6, label='Observed data')
# plt.plot(t_brandon, I_true, 'g',linewidth=2, label='True model output')
plt.plot(tmoh[:int(200*ndiv)], I[:int(200*ndiv),0], '-',linewidth=2, label='MLE fit')
plt.legend(loc='best')
plt.xlabel('Time (days)')
plt.xlim([0,200])
plt.ylim([0,3500])
plt.ylabel('Infected cases')
plt.grid()
# plt.savefig('./MLE_fit_all.pdf', bbox_inches='tight')
plt.show()




fig1, ax1 = plt.subplots(figsize=(6, 4))
# plt.plot(t[:tlim], I_synthetic[:tlim,0], '*', markersize=6, label='Observed data')
# plt.plot(t_brandon, b_true, 'g',linewidth=2, label='True model output')
plt.plot(tmoh[:int(tlim*ndiv)], beta_i, '-',linewidth=2, label='MLE fit')
plt.legend(loc='best')
plt.xlabel('Time (days)')
plt.xlim([0,160])
plt.ylim([0,0.30])
plt.ylabel('Infected cases')
plt.grid()
# plt.savefig('./MLE_fit_all.pdf', bbox_inches='tight')
plt.show()

# %%
print(param_mle)
# Out:
# [ 0.15       -0.1000742   0.06064663 -0.0891702   0.04714598  0.04359538
#   0.01      ]
